# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns 
from scipy.stats import pearsonr
# %matplotlib inline 
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import CountVectorizer
import numpy as np

# %%
df=pd.read_csv('top2018.csv')

# %%
df.columns
# Out:
# Index(['id', 'name', 'artists', 'danceability', 'energy', 'key', 'loudness',
#        'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness',
#        'valence', 'tempo', 'duration_ms', 'time_signature'],
#       dtype='object')

# %%
df['Duration_min']=df['duration_ms']/60000
df.drop(columns='duration_ms',inplace=True)

# %%
df['artists'].value_counts().head(10)
# Out:
# XXXTENTACION       6
# Post Malone        6
# Drake              4
# Marshmello         3
# Ed Sheeran         3
# Clean Bandit       2
# Khalid             2
# Ariana Grande      2
# Imagine Dragons    2
# Dua Lipa           2
# Name: artists, dtype: int64

# %%
##sns.set_style(style='darkgrid')
sns.distplot(df['danceability'],hist=True,kde=True)

# %%
cv=CountVectorizer()

# %%
data = np.matrix()
data[:, ['artists', 'energy']]
extractedData = data[:,[1,9]]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-cec271778ce9> in <module>
# ----> 1 data = np.matrix()
#       2 data[:, ['artists', 'energy']]
#       3 extractedData = data[:,[1,9]]
#
# TypeError: __new__() missing 1 required positional argument: 'data'

# %%
df.columns[:,[1,3]]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-78-7802e21a4226> in <module>
# ----> 1 df.columns[:,[1,3]]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in __getitem__(self, key)
#    3967
#    3968         key = com.values_from_object(key)
# -> 3969         result = getitem(key)
#    3970         if not is_scalar(result):
#    3971             return promote(result)
#
# IndexError: too many indices for array

# %%
ap= df[['artists']]
np.matrix(ap)
# Out:
# matrix([['Drake'],
#         ['XXXTENTACION'],
#         ['Post Malone'],
#         ['Post Malone'],
#         ['Drake'],
#         ['Post Malone'],
#         ['Cardi B'],
#         ['Calvin Harris'],
#         ['Dua Lipa'],
#         ['Marshmello'],
#         ['Camila Cabello'],
#         ['Juice WRLD'],
#         ['Drake'],
#         ['Maroon 5'],
#         ['Zedd'],
#         ['Kendrick Lamar'],
#         ['Ariana Grande'],
#         ['Nicky Jam'],
#         ['XXXTENTACION'],
#         ['BlocBoy JB'],
#         ['Rudimental'],
#         ['Nio Garcia'],
#         ['Bazzi'],
#         ['5 Seconds of Summer'],
#         ['Dua Lipa'],
#         ['Ed Sheeran'],
#         ['Khalid'],
#         ['Bebe Rexha'],
#         ['XXXTENTACION'],
#         ['Ed Sheeran'],
#         ['Tyga'],
#         ['Clean Bandit'],
#         ['Post Malone'],
#         ['Dennis Lloyd'],
#         ['Luis Fonsi'],
#         ['benny blanco'],
#         ['Camila Cabello'],
#         ['Selena Gomez'],
# ...

# %%
ap1= df[['energy']]
np.matrix(ap1)[::-1]
# Out:
# matrix([[0.586],
#         [0.437],
#         [0.76 ],
#         [0.658],
#         [0.619],
#         [0.57 ],
#         [0.704],
#         [0.505],
#         [0.346],
#         [0.768],
#         [0.493],
#         [0.679],
#         [0.664],
#         [0.539],
#         [0.738],
#         [0.299],
#         [0.805],
#         [0.621],
#         [0.816],
#         [0.296],
#         [0.519],
#         [0.813],
#         [0.895],
#         [0.804],
#         [0.654],
#         [0.731],
#         [0.628],
#         [0.677],
#         [0.795],
#         [0.708],
#         [0.798],
#         [0.597],
#         [0.649],
#         [0.788],
#         [0.658],
#         [0.761],
#         [0.712],
#         [0.533],
#         [0.412],
#         [0.683],
#         [0.745],
#         [0.75 ],
#         [0.764],
#         [0.785],
#         [0.387],
#         [0.78 ],
#         [0.599],
#         [0.375],
#         [0.792],
#         [0.428],
#         [0.598],
#         [0.721],
# ...

# %%
ap= df[['speechiness']]
#np.matrix(ap)

ap1= df[['energy']]
#np.matrix(ap1)[::-1]

ap2= df[['loudness']]
ap2=np.array(ap2)
a=ap2.tolist()
b=[]
for l in a:
    #print(l[0])
    b.append(l[0])
b
# Out:
# [-9.211,
#  -4.88,
#  -6.09,
#  -8.011000000000001,
#  -5.832999999999999,
#  -5.843,
#  -3.998,
#  -3.24,
#  -5.975,
#  -2.384,
#  -4.333,
#  -7.23,
#  -6.474,
#  -6.825,
#  -3.0610000000000004,
#  -4.946000000000001,
#  -5.507000000000001,
#  -4.736000000000001,
#  -5.723,
#  -7.495,
#  -4.0569999999999995,
#  -3.445,
#  -3.8739999999999997,
#  -5.114,
#  -6.021,
#  -3.1830000000000003,
#  -5.626,
#  -6.61,
#  -9.144,
#  -6.312,
#  -7.442,
#  -4.546,
#  -5.4079999999999995,
#  -8.354,
#  -3.655,
#  -7.648,
#  -4.333,
#  -4.59,
#  -10.068,
#  -5.335,
#  -5.916,
#  -3.4560000000000004,
#  -3.714,
#  -4.833,
#  -4.449,
#  -2.867,
#  -4.877,
#  -4.856,
#  -5.665,
#  -4.928999999999999,
#  -8.28,
#  -2.7489999999999997,
#  -8.279,
#  -5.042,
#  -4.374,
#  -9.127,
#  -4.65,
#  -4.399,
#  -6.3660000000000005,
#  -3.695,
#  -2.8810000000000002,
#  -8.074,
#  -9.74,
#  -7.321000000000001,
#  -3.093,
#  -5.934,
#  -4.323,
#  -5.892,
#  -5.131,
#  -4.206,
#  -4.154,
#  -5.115,
#  -4.979,
# ...

# %%
ap1= df[['energy']]
ap1=np.array(ap1)
c=[]
a=ap1.tolist()
for l in a:
    c.append(l[0])

# %%
from scipy import spatial
p=[1,2,3,4]
q=[-1,-2,-3,-4]
result = 1 - spatial.distance.cosine(p,q)
print(result)
# Out:
# -1.0

# %%
df
# Out:
#                        id                                               name  \
# 0   6DCZcSspjsKoFjzjrWoCd                                         God's Plan
# 1   3ee8Jmje8o58CHK66QrVC                                               SAD!
# 2   0e7ipj03S05BNilyu5bRz                         rockstar (feat. 21 Savage)
# 3   3swc6WTsr7rl9DqQKQA55                       Psycho (feat. Ty Dolla $ign)
# 4   2G7V7zsVDxg1yRsu7Ew9R                                     In My Feelings
# 5   7dt6x5M1jzdTEt8oCbisT                                         Better Now
# 6   58q2HKrzhC3ozto2nDdN4                                          I Like It
# 7   7ef4DlsgrMEH11cDZd32M                           One Kiss (with Dua Lipa)
# 8   76cy1WJvNGJTj78UqeA5z                                              IDGAF
# 9   08bNPGLD8AhKpnnERrAc6                                            FRIENDS
# 10  1rfofaqEpACxVEHIZBJe6                                             Havana
# ...

# %%
count = CountVectorizer()
count_matrix = count.fit_transform(np.matrix(ap))
count_matrix1 = count.fit_transform(np.matrix(ap1))

if self.lowercase:
    return lambda x: strip_accents(x.lower())
else: 
    return strip_accents
# creating a Series for the movie titles so they are associated to an ordered numerical
# list I will use later to match the indexes
